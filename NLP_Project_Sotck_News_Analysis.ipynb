# %%
import yfinance as yf
from transformers import pipeline

# %%
pipe_obj=pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
stocks=['ADANIENT.NS' , 'ADANIPORTS.NS' , 'APOLLOHOSP.NS' , 'ASIANPAINT.NS' , 'AXISBANK.NS' , 'BAJAJ-AUTO.NS' ,
    'BAJFINANCE.NS' , 'BAJAJFINSV.NS' , 'BPCL.NS' , 'BHARTIARTL.NS']

# %%
s=input()
# Out:
# BPCL.NS

# %%
stock_ticker=yf.Ticker(s)
stock_news=(stock_ticker.news[0])

# %%
news_full=stock_news['content']['title']+'.'+stock_news['content']['summary']
news_date=stock_news['content']['pubDate']
news_url=stock_news['content']['canonicalUrl']['url']

# %%
print(news_full,news_date,news_url)
# Out:
# India's BPCL plans to buy US oil via 4-mth tender, source says.Indian state refiner Bharat Petroleum Corp plans to float a 4-month tender next week to buy U.S. West Texas Intermediate (WTI) crude, a person familiar with the matter said on Friday, as it eyes cheaper oil from the world's top producer.  BPCL did not respond to Reuters request for comments.  The Indian refiner last year awarded a similar tender to European major BP. 2025-03-07T09:19:16Z https://sg.finance.yahoo.com/news/indias-bpcl-plans-buy-us-091916827.html

# %%
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
analysis=pipe_obj(news_full)
analysis
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9925341606140137}]
