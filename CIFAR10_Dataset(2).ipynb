# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train,y_train),(x_test,y_test)=tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
x_train_scaled=x_train/255

# %%
x_test_scale=x_test/255

# %%
classlabel = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
model=keras.Sequential([
    keras.layers.Flatten(),
    keras.layers.Dense(500,activation='relu'),
    keras.layers.Dense(10,activation='sigmoid')
])

model.compile(
    optimizer='SGD',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(x_train_scaled,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.2859 - loss: 1.9732
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.4005 - loss: 1.6976
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.4301 - loss: 1.6212
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.4502 - loss: 1.5653
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.4655 - loss: 1.5256

# %%
classlabel[np.argmax(model.predict(x_test_scale)[0])]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 'cat'

# %%
classlabel[y_test[0][0]]
# Out:
# 'cat'

# %%
model.evaluate(x_test_scale,y_test_categorical)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4307 - loss: 1.5928
# [1.5966180562973022, 0.4323999881744385]
