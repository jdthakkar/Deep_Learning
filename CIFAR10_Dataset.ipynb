# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
tf.config.experimental.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
(x_train,y_train),(x_test,y_test)=tf.keras.datasets.cifar10.load_data()

# %%
x_train_scaled=x_train/255

# %%
x_test_scale=x_test/255

# %%
y_train_categorical=keras.utils.to_categorical(y_train,num_classes=10)
y_test_categorical=keras.utils.to_categorical(y_test,num_classes=10)

# %%
classlabel = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
model=keras.Sequential([
    keras.layers.Flatten(),
    keras.layers.Dense(500,activation='relu'),
    keras.layers.Dense(10,activation='sigmoid')
])

model.compile(
    optimizer='SGD',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(x_train_scaled,y_train_categorical,epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.2897 - loss: 1.9787
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.4005 - loss: 1.7177
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - accuracy: 0.4280 - loss: 1.6285
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.4506 - loss: 1.5620
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.4669 - loss: 1.5175

# %%
classlabel[np.argmax(model.predict(x_test_scale)[1])]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 'truck'

# %%
classlabel[y_test[0][0]]
# Out:
# 'cat'

# %%
model.evaluate(x_test_scale,y_test_categorical)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4307 - loss: 1.5928
# [1.5966180562973022, 0.4323999881744385]
