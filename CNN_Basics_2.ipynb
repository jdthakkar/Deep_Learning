# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train,y_train),(x_test,y_test)=keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
y_train=y_train.reshape(-1,)

# %%
classes=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

# %%
def plot_img(x,y,index):
    plt.figure(figsize=(1,2))
    plt.imshow(x[index])
    plt.xlabel(classes[y[index]])
    plt.show()

# %%
plot_img(x_train,y_train,0)

# %%
x_train=x_train/255
x_test=x_test/255

# %%
cnn=keras.Sequential([
    keras.layers.Conv2D(filters=32,kernel_size=(3,3),activation='relu'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(64,activation='relu'),
    keras.layers.Dense(10,activation='softmax')
])

cnn.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

cnn.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 22ms/step - accuracy: 0.3767 - loss: 1.7083
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 21ms/step - accuracy: 0.5656 - loss: 1.2381
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 42s 22ms/step - accuracy: 0.6128 - loss: 1.1081
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 33s 21ms/step - accuracy: 0.6379 - loss: 1.0318
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.6639 - loss: 0.9608
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.6830 - loss: 0.9066
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 33s 21ms/step - accuracy: 0.6954 - loss: 0.8719
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 42s 22ms/step - accuracy: 0.7126 - loss: 0.8238
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.7255 - loss: 0.7764
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.7439 - loss: 0.7451

# %%
y_tets=y_test.reshape(-1,)

# %%
cnn.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6330 - loss: 1.0677
# [1.0865525007247925, 0.6341999769210815]

# %%
y_pred=cnn.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %%
y_pred_int=[np.argmax(e) for e in y_pred]

# %%
y_pred_int[190:195]
# Out:
# [np.int64(6), np.int64(8), np.int64(0), np.int64(1), np.int64(7)]

# %%
y_test[190:195]
# Out:
# array([[5],
#        [8],
#        [0],
#        [1],
#        [7]], dtype=uint8)
