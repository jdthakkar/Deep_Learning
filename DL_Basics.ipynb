# %%
import tensorflow as tf
from tensorflow import keras

# %%
(x_train, y_train),(x_test,y_test)= keras.datasets.mnist.load_data()

# %%
x_train=x_train/255
x_test=x_test/255

# %%
x_train_flattened=x_train.reshape(len(x_train),28*28)
x_test_flattened=x_test.reshape(len(x_test),28*28)

# %%
model=keras.Sequential([
    keras.layers.Dense(10,activation='sigmoid')
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(x_train_flattened,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8102 - loss: 0.7241
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9144 - loss: 0.3054
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9189 - loss: 0.2882
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9247 - loss: 0.2743
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9247 - loss: 0.2662

# %%
model.evaluate(x_test_flattened,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9147 - loss: 0.3025
# [0.266080766916275, 0.9262999892234802]

# %%
y_pred=model.predict(x_test_flattened)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
import numpy as np

y_pred_lables=[np.argmax(i) for i in y_pred]

# %%
y_pred_lables[0]
# Out:
# np.int64(7)

# %%
cm=tf.math.confusion_matrix(labels=y_test,predictions=y_pred_lables)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 954,    0,    3,    2,    0,    5,   10,    2,    3,    1],
#        [   0, 1111,    3,    2,    0,    1,    4,    2,   12,    0],
#        [   3,    9,  937,   13,    9,    3,   12,    9,   34,    3],
#        [   2,    0,   25,  917,    1,   27,    1,   11,   20,    6],
#        [   1,    1,    6,    0,  924,    0,    9,    3,   10,   28],
#        [   7,    3,    5,   29,   12,  782,   13,    5,   30,    6],
#        [   7,    3,    7,    1,    8,   14,  913,    2,    3,    0],
#        [   1,    8,   25,    6,    9,    0,    0,  944,    3,   32],
#        [   3,    8,    8,   21,    9,   30,    9,   11,  869,    6],
#        [   8,    7,    2,   10,   31,    8,    0,   23,    8,  912]],
#       dtype=int32)>

# %%
import seaborn as sns
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# <Axes: >

# %%
model=keras.Sequential([
    keras.layers.Dense(100,activation='relu'),
    keras.layers.Dense(10,activation='sigmoid')
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(x_train_flattened,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8751 - loss: 0.4454
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9618 - loss: 0.1311
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9759 - loss: 0.0830
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9815 - loss: 0.0624
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9861 - loss: 0.0481

# %%
model.evaluate(x_test_flattened,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9766 - loss: 0.0846
# [0.07586553692817688, 0.9782999753952026]

# %%
model=keras.Sequential([
    keras.layers.Flatten(),
    keras.layers.Dense(100,activation='relu'),
    keras.layers.Dense(10,activation='sigmoid')
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(x_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8717 - loss: 0.4525
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9605 - loss: 0.1334
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9737 - loss: 0.0858
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9809 - loss: 0.0650
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9855 - loss: 0.0471

# %%
import tensorflow_model_optimization as tfmo

# %%
quant_mod=tfmo.quantization.keras.quantize_model
quant_aware_mod=quant_mod(model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-0170a6c37dd9> in <cell line: 0>()
#       1 quant_mod=tfmo.quantization.keras.quantize_model
# ----> 2 quant_aware_mod=quant_mod(model)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow_model_optimization/python/core/quantization/keras/quantize.py in quantize_model(to_quantize, quantized_layer_name_prefix)
#     133       and to_quantize._is_graph_network
#     134   ):  # pylint: disable=protected-access
# --> 135     raise ValueError(
#     136         '`to_quantize` can only either be a keras Sequential or '
#     137         'Functional model.'
#
# ValueError: `to_quantize` can only either be a keras Sequential or Functional model.
